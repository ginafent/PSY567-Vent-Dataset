# %%
import pandas as pd

vents = pd.read_csv("ventsCleaned")
print(vents.head())
# Out:
#    Unnamed: 0                               post_id  \
# 0           0  a992d9f0-1b4c-4a6c-9d73-4cd7deb287ef
# 1           1  fe1ac197-3294-493f-ba9d-04c6bfbea10c
# 2           2  3180a95c-c03d-4a36-b78c-26d54d928049
# 3           3  e980b0f5-cf31-4f4d-a4d9-6b7dac19f8a3
# 4           4  858d2a6c-72f6-4162-9d3a-f11b306f8d91
#
#                                 user_id       emotion emotion_category  \
# 0  1a62fe90-d702-3051-b5fe-0a9c86adac56     Surprised         Surprise
# 1  f05733e9-078c-3413-848d-a30a7f502ee9      Stressed             Fear
# 2  336d37c1-9dfe-3454-a60d-dfa853f52bcc           Sad          Sadness
# 3  59ae0e0d-b58e-4b56-9d14-c8ed90d55302  Disappointed          Sadness
# 4  59ae0e0d-b58e-4b56-9d14-c8ed90d55302         Empty          Sadness
#
#    reactions  follower_count
# 0          0               0
# 1          6               0
# 2          0               0
# 3         10              19
# 4          8              19

# %% [markdown]
# Steps:
# 1. merge with time metadata
# 1. get all user's second ever post
# 1. save as subset

# %%
metadata = pd.read_csv("Vent/vents_metadata.csv")
